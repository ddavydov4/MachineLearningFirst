# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
state_web_site_feedback = pd.read_csv("/content/drive/MyDrive/data-20150923t1145-structure-20150923t1145_4.csv")

# %%
state_web_site_feedback.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16588 entries, 0 to 16587
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Уровень               16588 non-null  object
#  1   Сайт                  16588 non-null  object
#  2   Адрес                 16588 non-null  object
#  3   Дата сайта            16588 non-null  object
#  4   Тип субъекта          691 non-null    object
#  5   Подведомственность    15301 non-null  object
#  6   Дата отзыва           16588 non-null  object
#  7   Тип отзыва            16588 non-null  object
#  8   Заголовок             16588 non-null  object
#  9   Сообщение             16585 non-null  object
#  10  Ответ                 15442 non-null  object
#  11  Куратор               14741 non-null  object
#  12  Решение куратора      14267 non-null  object
#  13  Дата ответа куратора  14741 non-null  object
#  14  Статус                16588 non-null  object
# ...

# %%
state_web_site_feedback.groupby('Сайт')['Дата отзыва'].count().sort_values(ascending=False).head(5)
# Out:
# Сайт
# Федеральная служба судебных приставов                      9077
# Федеральная миграционная служба                            2102
# Федеральная налоговая служба                                933
# Официальный сайт Пенсионного фонда Российской Федерации     469
# Федеральная служба исполнения наказаний                     299
# Name: Дата отзыва, dtype: int64

# %%
state_web_site_feedback.groupby('Куратор')['Дата отзыва'].count().sort_values(ascending=False).head(5)
# Out:
# Куратор
# Ищенко Роман Вячеславович       3272
# Червинский Владимир Петрович    3099
# Демкин Павел Алексеевич         2159
# Сафонова Наталья Сергеевна      1598
# Копчикова Любовь Валерьевна      485
# Name: Дата отзыва, dtype: int64

# %%
state_web_site_feedback['нет ответа']=state_web_site_feedback.isna()['Ответ']

# %%
state_web_site_feedback
# Out:
#                   Уровень                                               Сайт  \
# 0             Федеральный   Министерство внутренних дел Российской Федерации
# 1             Федеральный  Министерство здравоохранения Российской Федерации
# 2             Федеральный  Министерство здравоохранения Российской Федерации
# 3             Федеральный  Министерство здравоохранения Российской Федерации
# 4             Федеральный  Министерство здравоохранения Российской Федерации
# ...                   ...                                                ...
# 16583  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16584  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16585  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16586  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16587  Активные участники  Федеральная служба по тарифам (Упразднена в со...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.barplot (data=state_web_site_feedback, x='Тип отзыва', y="нет ответа", hue="Подведомственность",)
# Out:
# <AxesSubplot:xlabel='Тип отзыва', ylabel='нет ответа'>

# %%
sns.barplot (data=state_web_site_feedback, x='Тип отзыва', y="нет ответа", hue="Уровень",)
# Out:
# <AxesSubplot:xlabel='Тип отзыва', ylabel='нет ответа'>

# %%
state_web_site_feedback['Дата отзыва'] = pd.to_datetime(state_web_site_feedback['Дата отзыва'])

# %%
state_web_site_feedback
# Out:
#                   Уровень                                               Сайт  \
# 0             Федеральный   Министерство внутренних дел Российской Федерации
# 1             Федеральный  Министерство здравоохранения Российской Федерации
# 2             Федеральный  Министерство здравоохранения Российской Федерации
# 3             Федеральный  Министерство здравоохранения Российской Федерации
# 4             Федеральный  Министерство здравоохранения Российской Федерации
# ...                   ...                                                ...
# 16583  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16584  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16585  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16586  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16587  Активные участники  Федеральная служба по тарифам (Упразднена в со...
#
# ...

# %%
state_web_site_feedback['День недели отзыва'] = state_web_site_feedback['Дата отзыва'].dt.dayofweek

# %%
state_web_site_feedback
# Out:
#                   Уровень                                               Сайт  \
# 0             Федеральный   Министерство внутренних дел Российской Федерации
# 1             Федеральный  Министерство здравоохранения Российской Федерации
# 2             Федеральный  Министерство здравоохранения Российской Федерации
# 3             Федеральный  Министерство здравоохранения Российской Федерации
# 4             Федеральный  Министерство здравоохранения Российской Федерации
# ...                   ...                                                ...
# 16583  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16584  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16585  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16586  Активные участники  Федеральная служба по тарифам (Упразднена в со...
# 16587  Активные участники  Федеральная служба по тарифам (Упразднена в со...
#
# ...

# %%
state_web_site_feedback.groupby('День недели отзыва')['Дата отзыва'].count().plot()
# Out:
# <AxesSubplot:xlabel='День недели отзыва'>

# %%
pd.pivot_table(state_web_site_feedback, columns="Тип отзыва",
               index="День недели отзыва",
               values="Уровень",
               aggfunc="count").plot.bar()
# Out:
# <AxesSubplot:xlabel='День недели отзыва'>

# %%
sds=pd.pivot_table(state_web_site_feedback, columns="Тип отзыва",
               index="День недели отзыва",
               values="Уровень",
               aggfunc="count")

# %%
sds.plot.bar()
# Out:
# <AxesSubplot:xlabel='День недели отзыва'>
